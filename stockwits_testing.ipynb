# %%
import pandas as pd
df = pd.read_json("stocks\AAPL\\409566868.json")
df
# Out:
#            id                                               text        time  \
# 0   409593559                     $AAPL Down 3-6% tomorrow sorry  1637692861
# 1   409593477  $AAPL all we need is a 25% day or week and hit...  1637692844
# 2   409592798                                $AAPL $200 PPS soon  1637692712
# 3   409590289  SIGNTIME filed for trademark by Apple Inc. htt...  1637692188
# 4   409589191  $800 million just from AAPL dividends a year $...  1637691968
# 5   409588561  $AAPL NEW ARTICLE : My Dividend Portfolio: Oct...  1637691847
# 6   409587357        $AAPL my average 165.5 now I’m a bag holder  1637691597
# 7   409586736  $AAPL 170$ next ✋ stop $SPY Follow my telegram...  1637691458
# 8   409585555                                   $AAPL Avg. 30.17  1637691216
# 9   409583600                                   $AAPL avg $59.23  1637690799
# 10  409582591       $AAPL Some price targets for tomorrow bulls?  1637690592
# 11  409582560                            $TSLA  $SPY  $AAPL $QQQ  1637690586
# 12  409581357  $SPOT vs $aapl not even close.. Spotify is by ...  1637690339
# 13  409581117  New market data is out now for $AAPL https://w...  1637690287
# 14  409580248  $AAPL this is how the bulls eating! Bears shou...  1637690106
# 15  409579599  $AAPL https://www.marketwatch.com/investing/st...  1637689972
# 16  409576413  $AAPL More of this news, please, thank you.\nh...  1637689319
# 17  409575884  $AMZN $NFLX $DIS $AAPL 90 minutes later, Futes...  1637689202
# 18  409574548  $AAPL my average= $42! People told me I was CR...  1637688929
# 19  409574176  $AAPL chart and rising volume tell us about a ...  1637688856
# 20  409573027                              $AAPL My average $125  1637688620
# 21  409572552                                $AAPL My avg is 141  1637688521
# 22  409571955                                  $AAPL my ave 149.  1637688400
# 23  409571874                                         $AAPL 🚀🙏✅💯  1637688385
# 24  409571753  $AAPL hope you bulls are only share holders an...  1637688364
# 25  409570844  $WIMI Metaverse, brings a new beginning, in wh...  1637688194
# 26  409570213  $AAPL \n\n#12 trending on Twitter the last 24h...  1637688064
# 27  409569246  $SPY $tsla $aapl $msft charts showing turkey a...  1637687876
# 28  409568823  $SPCE $AAPL $TSLA $WMT \nCheck out Volvo&#39;s...  1637687795
# 29  409566868                       $AAPL Let’s bounce back here  1637687415
#
#    sentiment
# 0    Bearish
# 1    Bullish
# 2    Bullish
# 3
# 4
# 5
# 6    Bearish
# 7    Bullish
# 8
# 9    Bullish
# 10   Bullish
# 11   Bullish
# 12   Bullish
# 13
# 14   Bullish
# 15
# 16   Bullish
# 17
# 18   Bullish
# 19
# 20   Bullish
# 21   Bullish
# 22   Bullish
# 23   Bullish
# 24
# 25   Bullish
# 26   Bullish
# 27   Bullish
# 28   Bullish
# 29   Bullish

# %%
import os, json
import pandas as pd

path_to_json = 'stocks/MSFT'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print("stocks/AAPL/"+json_files[0])
# Out:
# stocks/AAPL/417316233.json

# %%
import os, json
import pandas as pd

path_to_json = 'stocks/MSFT'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

df = pd.DataFrame()

for file in json_files:
    temp = pd.read_json("stocks/MSFT/"+file)
    df = df.append(temp, ignore_index=True)
print(df)
# Out:
#              id                                               text  \
# 0     416403662  $SNOW is every growth investor&#39;s dream sto...
# 1     416403044         $MSFT take me down to the tendie town city
# 2     416401083  @CHCInvestments @Dr_Stoxx They&#39;re too caug...
# 3     416399423                       $AAPL $AMZN $TSLA $MSFT $QQQ
# 4     416395656  $MSFT MSFT 2021-12-12 Options Analysis Video: ...
# ...         ...                                                ...
# 2215  418827479  $MSFT MSFT 2021-12-19 Daily Forecast Video: \n...
# 2216  418826794  $MSFT This and $AAPL are shelters in a storm m...
# 2217  418823319  SweepCast observed increasing unusual activity...
# 2218  418822931  $AAPL honestly, to professionals, it’s very ob...
# 2219  418820076  Trade Idea Recap $MSFT moved up to -3.81% sinc...
#
#             time sentiment
# 0     1639333417   Bullish
# 1     1639333176
# 2     1639332368   Bullish
# 3     1639331751
# 4     1639330336
# ...          ...       ...
# 2215  1639944373
# 2216  1639944114   Bearish
# 2217  1639942899
# 2218  1639942761
# 2219  1639941676
#
# [2220 rows x 4 columns]
