# %%
import pandas as pd
from pathlib import Path
import os

directory = Path(os.getcwd())   
directory = directory.parent.parent.joinpath("data") 
df = pd.read_pickle(directory.joinpath("stocktwits_processed_without_multiple_full.pkl"))
df
# Out:
#                id                                               text  \
# 0       411896118  I’m comfortable at $127.50. I’ll check back in...
# 1       411895020  how low does this POS go tomorrow is the milli...
# 2       411894156  @Nobrainer6868  started my first 5% position t...
# 3       411894124  You guys want me to sell down here? Look at th...
# 4       411893846  at this price point shorts are better off flip...
# ...           ...                                                ...
# 386926  420618061  USBancorp  BidaskScore is #Reiterated to Stron...
# 386927  420617596  Short sale volume (not short interest) for  on...
# 386928  420610698  SweepCast observed:  with Unusual Options Acti...
# 386929  420437859  How does this affect your portfolio? 's in Upt...
# 386930  420433589  MOVES HAPPENING NOW (8:25am)  ⦿  is down 0.0% ...
#
#               time sentiment symbols
# 0       1638291431   Bullish   $BABA
# 1       1638291222             $BABA
# 2       1638291057             $BABA
# 3       1638291050             $BABA
# 4       1638291000             $BABA
# ...            ...       ...     ...
# 386926  1640479505              $USB
# 386927  1640478214              $USB
# 386928  1640466364              $USB
# 386929  1640326224              $USB
# 386930  1640323511              $USB
#
# [384876 rows x 5 columns]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidf_top_n_words(df, threshold, target):
    # df to corpus
    corpus = []
    symbols = set(df.symbols)
    for i in symbols:
        corpus.append(". ".join([i.strip() for i in list(df[df['symbols']==i].text)]))

    # words to vector
    vectorizer = TfidfVectorizer(stop_words='english')
    vecs = vectorizer.fit_transform(corpus) # fit corpus
    feature_names = vectorizer.get_feature_names()
    dense = vecs.todense()
    lst1 = dense.tolist()
    # a dataframe with tf-idf scores
    df_tfidf = pd.DataFrame(lst1, columns=feature_names)
    data = df_tfidf.transpose()
    data.columns = list(symbols)

    df = data.sort_values(by=[target], ascending=False)
    df = df[df[target] > threshold]
    return df[target]

# %%
words = []
for i in set(df.symbols):
    result = tfidf_top_n_words(df, 0.1, i)
    print(list(result.index))
    words += (list(result.index))
# Out:
# ['oracle', 'cerner', 'orcl', '100', 'options', 'cloud', 'new']
# ['coca', 'cola', 'alerted', 'sweepcast', 'options', 'unusual', 'expiring', 'activity', 'worth', 'bodyarmor', 'allen', 'ko', 'new', '2022', 'company']
# ['300', 'nvidia', 'nvda', 'today', 'market', 'calls', 'buy', 'just', 'day', 'stock', 'going', 'like', 'tomorrow', 'week', 'time', '310']
# ['filing', '424b2', 'prospectus', '424', 'filed', 'form', 'chase', 'sec', 'rule', 'fwp', 'stockorbit', 'simulated', 'jpmorgan', 'dollar', 'morgan', 'calls', 'open']
# ['citigroup', 'simulated', 'stockorbit', 'calls', 'fwp', 'citi', 'dollar', 'open', 'prospectuses', 'options', '62', '433', 'filed', 'form', 'liquidtheta', 'sec', '163', 'tp2', 'tp3', '2022', 'inbox', 'tp1', 'buy', 'filing', 'optional']
# ['bitcoin', 'bears', 'btc', 'buy', 'crypto', 'just', '50k', 'like', 'going', 'time', 'lol', 'dubai', 'don', '60k', 'dip']
# ['bancorp', 'redemption', 'announces']
# ['jd', 'baba', 'china', 'hk', 'com', 'alerted', 'sweepcast', 'today']
# ['amazon', 'aws', 'amzn', '3500', '3400', 'stock', 'today', 'just', 'new', 'day', 'calls', '3450', 'market', '3600', 'time', 'going', 'tomorrow', 'like']
# ['walton', 'walmart', 'waltons', 'wmt', 'shares', 'robson', '140', 'options', 'alice']
# ['disney', 'walt', 'calls', 'simulated', 'stockorbit', 'dis', 'new', 'open', 'dollar', '155', '157', 'stock']
# ['intel', 'mobileye', 'stockorbit', 'simulated', 'calls', 'dollar', 'open', 'intc', '50', 'stock']
# ['paypal', 'pypl', 'market', '200', 'buy', '190', 'today', 'stock', 'calls', 'just', 'day', 'like', 'going', 'price', '195', 'stockorbit', 'simulated']
# ['microsoft', 'calls', 'stockorbit', 'simulated', 'msft', 'options', 'market', 'open', 'dollar', '337', '340', 'today', 'buy', 'stocks', '12', '330', 'trading', 'stock', 'elliottwave', 'tomorrow']
# ['exxon', 'mobil', 'simulated', 'stockorbit', 'dollar', '62', 'calls', 'xom', 'exxonmobil', 'open', 'options', 'alerted']
# ['twtr', 'fb', 'dwac', 'trump', 'scam', 'qqq']
# ['mastercard', 'stockorbit', 'simulated', 'calls', 'dollar', 'open', 'liquidtheta', 'tp3', 'tp2', 'tp1', 'inbox', 'optional', 'options', '342', '352', 'alerted', '2022', 'unusual', 'sweepcast', 'actionable', 'price', 'buy']
# ['google', 'elliottwave', 'trading', '3000', '2960', 'alerted', '10', 'sweepcast', 'update', 'googl', '4hr', 'presented', 'view', 'unusual', '2021', 'term', 'worth', 'members', 'long', 'options', 'expiring', 'alphabet']
# ['goldman', 'fwp', 'sachs', 'liquidtheta', 'tp3', 'tp2', 'inbox', 'tp1', 'filed', 'form', 'options', 'optional', 'alerted', 'delayed', 'sweepcast', '2022', 'unusual', 'sec', 'prospectuses', 'actionable', '00', '433', 'expiring', 'group', 'price']
# ['starbucks', 'stockorbit', 'simulated', 'calls', 'dollar', 'open', 'alerted', 'sweepcast']
# ['bitcoin', 'btc', 'bears', 'just', 'crypto', 'buy', 'going', 'like', 'time', 'don', '50k', 'bitty', 'market']
# ['elon', 'tesla', 'today', 'musk', 'selling', 'just', 'stock', 'tsla', 'buy', 'going', 'bears', 'shares', 'like', 'market', 'sell', 'tomorrow']
# ['hsbc', 'filed', 'form', '15d', '13a', 'issuer', '16', 'plc', 'sec', 'foreign', 'delayed', 'rules', 'holdings', 'alerted', 'unusual']
# ['ubs', 'advisor', 'joins', 'delayed', 'french', 'ag', 'diane', 'johnston', '45', 'jericho', 'brett', 'form', 'seconds', 'filed', '15d', '13a']
# ['stockorbit', 'simulated', 'calls', 'semiconductor', 'taiwan', 'tsm', 'dollar', 'open', 'options', 'liquidtheta', 'tp2', 'tp3', '120', 'tp1', 'inbox', 'optional', 'alerted', '2022', 'buy', '122', 'sweepcast', 'unusual', 'long']
# ['qqq', 'iwm', 'dia', 'aapl', 'tsla', 'djia', 'baba']
# ['unitedhealth', 'health', 'unitedhealthcare', 'unusual', 'group', 'alerted', 'sweepcast', 'options', 'expiring', '2021', 'colorado', 'donates', 'activity']
# ['fwp', 'filed', 'form', 'prospectuses', '433', 'sec', 'stanley', 'filing', '163', 'morgan', 'writing', 'delayed', 'rules', 'act', 'securities', '15s']
# ['apple', 'aapl', 'market', 'calls', 'bears', 'just', 'puts', 'buy', 'today', 'going', '170', '180', 'like', 'stock', '175', 'tomorrow', 'week', '200', 'time', '177', 'day']
# ['market', 'just', 'today', 'puts', 'day', 'going', 'like', 'tomorrow', 'calls', 'qqq', 'buy', 'time', 'week', 'bears', '400', 'good', 'lol', 'rally']
# ['stockorbit', 'simulated', 'calls', '45', 'options', 'dollar', 'open', 'america', 'activity', 'bank', 'sweep', '44', 'market', 'contracts', 'trading', 'fwp', 'monday', 'alerted', 'unusual']
# ['qualcomm', 'qcom', 'alerted', 'long', 'sweepcast', '200', 'today', 'options', 'unusual']
# ['baba', 'china', 'alibaba', 'hk', 'delisting', 'chinese', 'buy', 'just', 'stock', 'day', 'like', 'going', 'today', 'market']
# ['netflix', 'stockorbit', 'simulated', 'calls', 'dollar', 'open', 'nflx', '700', 'alerted', 'sweepcast', 'unusual']
# ['visa']
# ['johnson', 'jnj', 'vaccine', 'alerted', 'sweepcast']
# ['ebay', 'alerted', 'sweepcast', 'options', 'unusual', 'activity', 'expiring', 'sneaker', 'worth', '2021']
# ['twitter', 'twtr', 'simulated', 'stockorbit', 'calls', 'dollar', 'open', 'new', 'stock', 'company', 'dorsey', 'just', 'like', '46', 'ceo', '50', 'going']
# ['facebook', 'meta', 'fb', 'calls', 'stock', 'market', 'buy', 'metaverse', 'today', '340', 'just', 'elliottwave', 'like', 'trading', '330', 'options']

# %%
import collections

final_words = []
occurrences = collections.Counter(words)
occurrences
# Out:
# Counter({'oracle': 1,
#          'cerner': 1,
#          'orcl': 1,
#          '100': 1,
#          'options': 15,
#          'cloud': 1,
#          'new': 5,
#          'coca': 1,
#          'cola': 1,
#          'alerted': 15,
#          'sweepcast': 12,
#          'unusual': 11,
#          'expiring': 5,
#          'activity': 4,
#          'worth': 3,
#          'bodyarmor': 1,
#          'allen': 1,
#          'ko': 1,
#          '2022': 5,
#          'company': 2,
#          '300': 1,
#          'nvidia': 1,
#          'nvda': 1,
#          'today': 11,
#          'market': 11,
#          'calls': 18,
#          'buy': 13,
#          'just': 11,
#          'day': 6,
#          'stock': 11,
#          'going': 10,
#          'like': 11,
#          'tomorrow': 6,
#          'week': 3,
#          'time': 6,
#          '310': 1,
#          'filing': 3,
#          '424b2': 1,
#          'prospectus': 1,
#          '424': 1,
#          'filed': 6,
#          'form': 6,
#          'chase': 1,
#          'sec': 5,
#          'rule': 1,
#          'fwp': 5,
#          'stockorbit': 13,
#          'simulated': 13,
#          'jpmorgan': 1,
#          'dollar': 12,
#          'morgan': 2,
#          'open': 12,
#          'citigroup': 1,
#          'citi': 1,
#          'prospectuses': 3,
#          '62': 2,
#          '433': 3,
#          'liquidtheta': 4,
#          '163': 2,
#          'tp2': 4,
#          'tp3': 4,
#          'inbox': 4,
#          'tp1': 4,
#          'optional': 4,
#          'bitcoin': 2,
#          'bears': 5,
#          'btc': 2,
#          'crypto': 2,
#          '50k': 2,
#          'lol': 2,
#          'dubai': 1,
#          'don': 2,
#          '60k': 1,
#          'dip': 1,
#          'bancorp': 1,
#          'redemption': 1,
#          'announces': 1,
#          'jd': 1,
#          'baba': 3,
#          'china': 2,
#          'hk': 2,
#          'com': 1,
#          'amazon': 1,
#          'aws': 1,
#          'amzn': 1,
#          '3500': 1,
#          '3400': 1,
#          '3450': 1,
#          '3600': 1,
#          'walton': 1,
#          'walmart': 1,
#          'waltons': 1,
#          'wmt': 1,
#          'shares': 2,
#          'robson': 1,
#          '140': 1,
#          'alice': 1,
#          'disney': 1,
#          'walt': 1,
#          'dis': 1,
#          '155': 1,
#          '157': 1,
#          'intel': 1,
#          'mobileye': 1,
#          'intc': 1,
#          '50': 2,
#          'paypal': 1,
#          'pypl': 1,
#          '200': 3,
#          '190': 1,
#          'price': 3,
#          '195': 1,
#          'microsoft': 1,
#          'msft': 1,
#          '337': 1,
#          '340': 2,
#          'stocks': 1,
#          '12': 1,
#          '330': 2,
#          'trading': 4,
#          'elliottwave': 3,
#          'exxon': 1,
#          'mobil': 1,
#          'xom': 1,
#          'exxonmobil': 1,
#          'twtr': 2,
#          'fb': 2,
#          'dwac': 1,
#          'trump': 1,
#          'scam': 1,
#          'qqq': 3,
#          'mastercard': 1,
#          '342': 1,
#          '352': 1,
#          'actionable': 2,
#          'google': 1,
#          '3000': 1,
#          '2960': 1,
#          '10': 1,
#          'update': 1,
#          'googl': 1,
#          '4hr': 1,
#          'presented': 1,
#          'view': 1,
#          '2021': 3,
#          'term': 1,
#          'members': 1,
#          'long': 3,
#          'alphabet': 1,
#          'goldman': 1,
#          'sachs': 1,
#          'delayed': 4,
#          '00': 1,
#          'group': 2,
#          'starbucks': 1,
#          'bitty': 1,
#          'elon': 1,
#          'tesla': 1,
#          'musk': 1,
#          'selling': 1,
#          'tsla': 2,
#          'sell': 1,
#          'hsbc': 1,
#          '15d': 2,
#          '13a': 2,
#          'issuer': 1,
#          '16': 1,
#          'plc': 1,
#          'foreign': 1,
#          'rules': 2,
#          'holdings': 1,
#          'ubs': 1,
#          'advisor': 1,
#          'joins': 1,
#          'french': 1,
#          'ag': 1,
#          'diane': 1,
#          'johnston': 1,
#          '45': 2,
#          'jericho': 1,
#          'brett': 1,
#          'seconds': 1,
#          'semiconductor': 1,
#          'taiwan': 1,
#          'tsm': 1,
#          '120': 1,
#          '122': 1,
#          'iwm': 1,
#          'dia': 1,
#          'aapl': 2,
#          'djia': 1,
#          'unitedhealth': 1,
#          'health': 1,
#          'unitedhealthcare': 1,
#          'colorado': 1,
#          'donates': 1,
#          'stanley': 1,
#          'writing': 1,
#          'act': 1,
#          'securities': 1,
#          '15s': 1,
#          'apple': 1,
#          'puts': 2,
#          '170': 1,
#          '180': 1,
#          '175': 1,
#          '177': 1,
#          '400': 1,
#          'good': 1,
#          'rally': 1,
#          'america': 1,
#          'bank': 1,
#          'sweep': 1,
#          '44': 1,
#          'contracts': 1,
#          'monday': 1,
#          'qualcomm': 1,
#          'qcom': 1,
#          'alibaba': 1,
#          'delisting': 1,
#          'chinese': 1,
#          'netflix': 1,
#          'nflx': 1,
#          '700': 1,
#          'visa': 1,
#          'johnson': 1,
#          'jnj': 1,
#          'vaccine': 1,
#          'ebay': 1,
#          'sneaker': 1,
#          'twitter': 1,
#          'dorsey': 1,
#          '46': 1,
#          'ceo': 1,
#          'facebook': 1,
#          'meta': 1,
#          'metaverse': 1})

# %%
remove_threshold = 0.125
for i in occurrences:
    if occurrences[i] > len(set(df.symbols)) * remove_threshold:
        print('REMOVED: ',i)
    else:
        final_words.append(i)
# Out:
# REMOVED:  options
# REMOVED:  new
# REMOVED:  alerted
# REMOVED:  sweepcast
# REMOVED:  unusual
# REMOVED:  expiring
# REMOVED:  2022
# REMOVED:  today
# REMOVED:  market
# REMOVED:  calls
# REMOVED:  buy
# REMOVED:  just
# REMOVED:  day
# REMOVED:  stock
# REMOVED:  going
# REMOVED:  like
# REMOVED:  tomorrow
# REMOVED:  time
# REMOVED:  filed
# REMOVED:  form
# REMOVED:  sec
# REMOVED:  fwp
# REMOVED:  stockorbit
# REMOVED:  simulated
# REMOVED:  dollar
# REMOVED:  open
# REMOVED:  bears

# %%
final_words
# Out:
# ['oracle',
#  'cerner',
#  'orcl',
#  'cloud',
#  'coca',
#  'cola',
#  'bodyarmor',
#  'allen',
#  'ko',
#  'coke',
#  'herbert',
#  'nvidia',
#  'nvda',
#  '310',
#  'arm',
#  '320',
#  '290',
#  '305',
#  '330',
#  '280',
#  'nasdaq',
#  '424b2',
#  'prospectus',
#  '424',
#  'chase',
#  'rule',
#  'jpmorgan',
#  '162',
#  'jp',
#  'citigroup',
#  'citi',
#  'prospectuses',
#  '433',
#  'liquidtheta',
#  '163',
#  'tp3',
#  'tp2',
#  'inbox',
#  'tp1',
#  'optional',
#  'writing',
#  'actionable',
#  'bitcoin',
#  'btc',
#  '50k',
#  'dubai',
#  '60k',
#  '100k',
#  'salvador',
#  'coins',
#  '42k',
#  'bancorp',
#  'redemption',
#  'depositary',
#  'jd',
#  'baba',
#  'hk',
#  'tencent',
#  'chinese',
#  'kong',
#  'hsi',
#  'amazon',
#  'aws',
#  'amzn',
#  '3500',
#  '3400',
#  '3450',
#  '3600',
#  'split',
#  'outage',
#  '3550',
#  '3300',
#  'walton',
#  'walmart',
#  'waltons',
#  'wmt',
#  'robson',
#  '140',
#  'alice',
#  'disney',
#  'walt',
#  'dis',
#  '155',
#  '157',
#  'parks',
#  'intel',
#  'mobileye',
#  'intc',
#  'paypal',
#  'pypl',
#  '190',
#  '195',
#  '192',
#  '187',
#  '180',
#  '188',
#  'microsoft',
#  'msft',
#  '337',
#  '340',
#  '335',
#  '327',
#  '325',
#  'exxon',
#  'mobil',
#  'xom',
#  'exxonmobil',
#  'oil',
#  'twtr',
#  'fb',
#  'dwac',
#  'trump',
#  'scam',
#  'qqq',
#  'mastercard',
#  '342',
#  '352',
#  'profitable',
#  'google',
#  '3000',
#  '2960',
#  'googl',
#  '4hr',
#  'presented',
#  'alphabet',
#  '2900',
#  '1hr',
#  'xceptional',
#  'blue',
#  'goldman',
#  'sachs',
#  '390',
#  'starbucks',
#  'sbux',
#  '115',
#  'bitty',
#  'elon',
#  'tesla',
#  'musk',
#  'tsla',
#  '1100',
#  '1000',
#  '900',
#  '1200',
#  '950',
#  '1050',
#  'hsbc',
#  '13a',
#  '15d',
#  'issuer',
#  'plc',
#  'foreign',
#  'ubs',
#  'advisor',
#  'joins',
#  'french',
#  'ag',
#  'diane',
#  'johnston',
#  'brett',
#  'jericho',
#  'kalyn',
#  'maher',
#  'beverly',
#  'canonsburg',
#  'undra',
#  'semiconductor',
#  'taiwan',
#  'tsm',
#  '120',
#  '122',
#  'tsmc',
#  'iwm',
#  'dia',
#  'aapl',
#  'djia',
#  'unitedhealth',
#  'unitedhealthcare',
#  'colorado',
#  'donates',
#  'youthzone',
#  'diego',
#  'unh',
#  'stanley',
#  'apple',
#  '170',
#  '175',
#  '177',
#  'iphone',
#  '3t',
#  'hoodies',
#  'etf',
#  '380',
#  '398',
#  'futures',
#  '395',
#  '385',
#  '397',
#  'powell',
#  '401',
#  'futes',
#  '383',
#  '392',
#  'bac',
#  'corporation',
#  'urgently',
#  'qualcomm',
#  'qcom',
#  'alibaba',
#  'delisting',
#  'ccp',
#  'delisted',
#  'delist',
#  'xi',
#  'netflix',
#  'nflx',
#  '700',
#  '620',
#  '690',
#  '610',
#  '655',
#  'visa',
#  'johnson',
#  'jnj',
#  'vaccine',
#  'ebay',
#  'sneaker',
#  'dorsey',
#  'parag',
#  'cathie',
#  'agrawal',
#  'jack',
#  'bird',
#  'facebook',
#  'meta',
#  'metaverse',
#  'instagram']

# %%
with open('tfidf_words/tfidf_words.txt', 'w') as filehandle:
    for listitem in final_words:
        filehandle.write('%s\n' % listitem)
