# %%
import pandas as pd
from pathlib import Path
import os

directory = Path(os.getcwd())   # 'c:\\Users\\samue\\OneDrive\\Desktop\\JPM Fintech\\HKUST-x-J.P.-Morgan-Fintech-Mentorship-Program\\model_testing\\supervised'
directory = directory.parent.parent.joinpath("data")  # 'c:\\Users\\samue\\OneDrive\\Desktop\\JPM Fintech\\data'
df = pd.read_pickle(directory.joinpath("stocktwits_raw_sample.pkl"))
df
# Out:
#               id                                               text  \
# 0      417739155  $GOEV it’s so easy to see insiders buying befo...
# 1      417739053  $QQQ $AAPL $SPY $NDX Santa’s rally has an addr...
# 2      417738922  $AAPL Futures Ripping Means \nAAPL up 2% to 4%...
# 3      417738486                               $AAPL pullback today
# 4      417738230  $AAPL look! The teddy bear picnic is starting!...
# ...          ...                                                ...
# 47815  419624841  $PYPL $V holding up well to the long side. $MC...
# 47816  419623909  $V $MSFT $MMM $HPQ suggested for $XMI US ARCA ...
# 47817  419618889      $SQ and $V  similar charts.  We will see $180
# 47818  419605709  $V damn putting in some work last couple of we...
# 47819  419593096  $V [Dec-23 212.50 Puts] Option volume Up +400....
#
#              time sentiment
# 0      1639643526
# 1      1639643425
# 2      1639643308
# 3      1639642896   Bearish
# 4      1639642665   Bullish
# ...

# %%
for i in df.sample(1000).text:
    if 'http' in i:
        print(i)
# Out:
# SweepCast observed increasing unusual activity on: $AAPL with Unusual Options Activity Alerted on $175 CALL Expiring: 12-17-2021 worth 26K🐂 https://www.sweepcast.com/optionflow?symbol=AAPL&amp;name=CALL&amp;strike=$175&amp;type=SWEEP&amp;pre=$26K&amp;exp=12-17-2021
# $JPM [15s. delayed] filed form 424B3 on December 10, 15:34:43 https://s.flashalert.me/7aQGD
# $TSLA Good News continued!!
#
#  GS Reiterates Buy Rating on Moderna  Following Prelim Omicron Data http://www.streetinsider.com/Analyst+Comments/Goldman+Sachs+Reiterates+Buy+Rating+on+Moderna+%28MRNA%29+Following+Preliminary+Omicron+Data/19373613.html
#
# Moderna noted that a 50µg booster dose increased neutralizing antibody levels against Omicron by ~37-fold &amp;  100µg booster dose increased neutralizing antibody levels ~83-fold
#
# Good Omicron News!!
# ICYMI - 20 STOCKS AND ALL THE KEY LEVELS TO WATCH.
# All tickers covered in detail.
# $AVGO $FB $GOOG $ABNB and is $INMD a buy here?  plus many more charts.
# ...

# %%
import pandas as pd
df1 = pd.read_csv(r"C:\Users\samue\OneDrive\Desktop\JPM Fintech\data\stockerbot-export.csv", error_bad_lines=False)
df1.symbols.value_counts()
# Out:
# C:\Users\samue\anaconda3\envs\jpm\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 731: expected 8 fields, saw 13\nSkipping line 2836: expected 8 fields, saw 15\nSkipping line 3058: expected 8 fields, saw 12\nSkipping line 3113: expected 8 fields, saw 12\nSkipping line 3194: expected 8 fields, saw 17\nSkipping line 3205: expected 8 fields, saw 17\nSkipping line 3255: expected 8 fields, saw 17\nSkipping line 3520: expected 8 fields, saw 17\nSkipping line 4078: expected 8 fields, saw 17\nSkipping line 4087: expected 8 fields, saw 17\nSkipping line 4088: expected 8 fields, saw 17\nSkipping line 4499: expected 8 fields, saw 12\n'
# NFLX             101
# AMAT             100
# GPS              100
# MOMO             100
# HON              100
#                 ...
# INTC-USB           1
# ...

# %%
for i in range(30):
    print(df1.iloc[i].text,'\t',df1.iloc[i].symbols)
# Out:
# VIDEO: “I was in my office. I was minding my own business...” –David Solomon tells $GS interns how he learned he wa… https://t.co/QClAITywXV 	 GS
# The price of lumber $LB_F is down 22% since hitting its YTD highs. The Macy's $M turnaround is still happening.… https://t.co/XnKsV4De39 	 M
# Who says the American Dream is dead? https://t.co/CRgx19x7sA 	 AIG
# Barry Silbert is extremely optimistic on bitcoin -- but predicts that 99% of new crypto entrants are “going to zero… https://t.co/mGMVo2cZgY 	 BTC
# How satellites avoid attacks and space junk while circling the Earth https://t.co/aHzIV3Lqp5 #paid @Oracle https://t.co/kacpqZWiDJ 	 ORCL
# .@RealMoney's David Butler's favorite FANG stock isn't #RealMoneySOD Alphabet but Facebook https://t.co/MczAPSFjOi 	 FB-GOOGL-GOOG
# Don’t miss my convo with one of my favorite thinkers @SamHarrisOrg! https://t.co/uuPVxIobCh 	 HRS
# ...
