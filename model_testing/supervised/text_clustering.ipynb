# %%
import pandas as pd
from pathlib import Path
import os

sample = 1000

directory = Path(os.getcwd())   # 'c:\\Users\\samue\\OneDrive\\Desktop\\JPM Fintech\\HKUST-x-J.P.-Morgan-Fintech-Mentorship-Program\\model_testing\\supervised'
directory = directory.parent.parent.parent.joinpath("data")  # 'c:\\Users\\samue\\OneDrive\\Desktop\\JPM Fintech\\data'
df = pd.read_pickle(directory.joinpath("stocktwits_processed_sample.pkl"))
df = df.groupby('symbols').filter(lambda x : len(x)>sample)
df['symbols'].value_counts()
# Out:
# $TSLA    20791
# $AAPL     9564
# $FB       5976
# $PYPL     5240
# $MSFT     4940
# $SPY      2969
# $BAC      1406
# $JPM      1363
# $JD       1253
# $V        1218
# $QQQ      1135
# $AMZN     1047
# Name: symbols, dtype: int64

# %%
from sentence_transformers import SentenceTransformer, util
import os
import csv
import time


# Model for computing sentence embeddings. We use one trained for similar questions detection
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Encode the corpus. This might take a while
# Batches: 100%|██████████| 150/150 [01:24<00:00,  1.78it/s]
# Start clustering
# Clustering done after 0.69 sec
#
# Cluster 1, #368 Elements
# 	      .
# 	      .
# 	 ..
# 	 ...
#
#
#
#
# Cluster 2, #139 Elements
#
# 🤬🤬🤬🤫🤫🤫👀👀
# 	     🔥🔥🔥🔥
#
# 🤮🤮🤮
# 	 ...
# 	      . 🗞 .
#
#
# 	      . 🗞 .
#
#
# 	      . 🗞 .
#
#
#
# Cluster 3, #40 Elements
# 	 The Santa Rally is on!
# 	 The Santa Rally is on!
#
#
# Santa Rally is here
# 	 ...
# 	   Turns out the Santa rally was for the bears this year. 😅
# 	  what SANTA rally? I think this was better off with all the omicron news lol
# 	  free fall or we got santa rally breaks?
#
# Cluster 4, #34 Elements
# 	  Simulated 182.5 dollar CALLS for Friday's open on StockOrbit.
#
# 	  Simulated 182.5 dollar CALLS for Friday's open on StockOrbit.
#
# 	  Simulated 182.5 dollar CALLS for Friday's open on StockOrbit.
#
# 	 ...
# 	  Simulated 175.0 dollar CALLS for Monday's open on StockOrbit.
#
# 	  Simulated 175.0 dollar CALLS for Monday's open on StockOrbit.
#
# 	  Simulated 175.0 dollar CALLS for Monday's open on StockOrbit.
#
#
# Cluster 5, #32 Elements
# 	  160P Exp:20-Jan-23 ↓  🔥 Total(Day): $28,980
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
# 	  210C Exp:18-Feb-22 ↑↑  🚀 Total(Day): $135,100
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
# 	  210C Exp:18-Feb-22 ↑↑  🚀 Total(Day): $135,100
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
# 	 ...
# 	  180C Exp:17-Dec-21 --  🚀 <R> Total(Day): $107,548
#  180C Exp:23-Dec-21 ↑↑  🚀 <R> Total(Day): $576,090
#  182.5C Exp:31-Dec-21 ↑↑  🚀 Total(Day): $85,618
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
# 	  180C Exp:17-Dec-21 --  🚀 <R> Total(Day): $107,548
#  180C Exp:23-Dec-21 ↑↑  🚀 <R> Total(Day): $576,090
#  182.5C Exp:31-Dec-21 ↑↑  🚀 Total(Day): $85,618
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
# 	  180C Exp:17-Dec-21 --  🚀 <R> Total(Day): $107,548
#  180C Exp:23-Dec-21 ↑↑  🚀 <R> Total(Day): $576,090
#  182.5C Exp:31-Dec-21 ↑↑  🚀 Total(Day): $85,618
# #UnusualActivity
#
#
# Sign-up free for beta
# charts: courtesy of finviz
#
# Cluster 6, #28 Elements
# 	  AAPL 2021-12-15 Dark Pool & Short Interest Data:
#
# 	  AAPL 2021-12-15 Dark Pool & Short Interest Data:
#
# 	  AAPL 2021-12-20 Dark Pool & Short Interest Data:
#
# 	 ...
# 	  AAPL 2021-12-19 Dark Pool & Short Interest Data:
#
# 	  AAPL 2021-12-19 Dark Pool & Short Interest Data:
#
# 	  AAPL 2021-12-19 Dark Pool & Short Interest Data:
#
#
# Cluster 7, #28 Elements
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
# 	 ...
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
# 	  was analyzed by 48 analysts. The buy consensus is at 83%. So analysts seem to be very confident about .
#
# Cluster 8, #25 Elements
# 	      December 28th FIRST TO MARKET Global Gold Exchange AABBG.X with 200+ trading pairs 5 Gold mines this will become the New Global Standard of Exchange and a Global currency anomaly as fiat has lost 98% of it's value since 1971 GOLD is KING! The GOLDEN CROSS!
# 	      December 28th FIRST TO MARKET Global Gold Exchange AABBG.X with 200+ trading pairs 5 Gold mines this will become the New Global Standard of Exchange and a Global currency anomaly as fiat has lost 98% of it's value since 1971 GOLD is KING! The GOLDEN CROSS!
# 	      December 28th FIRST TO MARKET Global Gold Exchange AABBG.X with 200+ trading pairs 5 Gold mines this will become the New Global Standard of Exchange and a Global currency anomaly as fiat has lost 98% of it's value since 1971 GOLD is KING! The GOLDEN CROSS!
# 	 ...
# 	       GOLD MINES>Global Exchange 218 tradind pairs featuring AABBG.X FIRST TO MARKET GlobalGold currency system!! VISIONARY>REVOLUTIONARY>Inflation proof
# 	 $TSLA    Watch List AABB Dec 28th Exchange goes ''live'' 200+ trading pairs featuring AABBG.X Gold backed cryptocurrency coin (mine to token) GOLDEN CROSS has commenced. FIRST to MARKET Global Gold currency system!!!
# 	 $TSLA    Watch List AABB Dec 28th Exchange goes ''live'' 200+ trading pairs featuring AABBG.X Gold backed cryptocurrency coin (mine to token) GOLDEN CROSS has commenced. FIRST to MARKET Global Gold currency system!!!

# %%
corpus_sentences = list(df[df['symbols'] == "$AAPL"].text)
print("Encode the corpus. This might take a while")
corpus_embeddings = model.encode(corpus_sentences, batch_size=64, show_progress_bar=True, convert_to_tensor=True)


print("Start clustering")
start_time = time.time()

#Two parameters to tune:
#min_cluster_size: Only consider cluster that have at least 25 elements
#threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
clusters = util.community_detection(corpus_embeddings, min_community_size=25, threshold=0.75)

print("Clustering done after {:.2f} sec".format(time.time() - start_time))

#Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", corpus_sentences[sentence_id])
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", corpus_sentences[sentence_id])
